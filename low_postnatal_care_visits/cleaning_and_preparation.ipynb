# %%
# Import necessary libraries

import pandas as pd

# %%
mothers_hmis_df = pd.read_csv('data/mothers_hmis.csv')
facilities_lookup_df = pd.read_csv('data/facilities_lookup.csv')
prompts_engagement_df = pd.read_csv('data/prompts_engagement.csv')

# %%
mothers_hmis_df.head()
# Out:
#    mother_id facility_id   county residence_type  age age_group  parity  \
# 0          1        F028   Kilifi          rural   36     35-49       4
# 1          2        F007   Kiambu     peri_urban   34     25-34       4
# 2          3        F002  Nairobi          urban   30     25-34       1
# 3          4        F019  Kajiado     peri_urban   17     15-19       0
# 4          5        F019  Kajiado     peri_urban   24     20-24       2
#
#   delivery_date delivery_mode complication_delivery  \
# 0    2024-10-17            CS                  none
# 1    2024-07-23           SVD                 other
# 2    2024-03-21           SVD                sepsis
# 3    2024-03-23           SVD                  none
# 4    2024-11-06           SVD                  none
#
#    postpartum_complication_6w postnatal_visit_date_1  postnatal_visit_6w  \
# 0                           0             2024-11-18                   1
# ...

# %%
facilities_lookup_df.head()
# Out:
#   facility_id       facility_name   county  facility_level  facility_type  \
# 0        F001  Nairobi Facility 1  Nairobi               2     dispensary
# 1        F002  Nairobi Facility 2  Nairobi               4  health_center
# 2        F003  Nairobi Facility 3  Nairobi               3  health_center
# 3        F004  Nairobi Facility 4  Nairobi               2     dispensary
# 4        F005  Nairobi Facility 5  Nairobi               5     dispensary
#
#   setting
# 0   urban
# 1   urban
# 2   urban
# 3   urban
# 4   urban

# %%
prompts_engagement_df.head()
# Out:
#   prompts_mother_id  mother_id registration_channel  \
# 0            P00001          2        community_CHV
# 1            P00002          4        community_CHV
# 2            P00003          5             facility
# 3            P00004          6          self_enroll
# 4            P00005          7        community_CHV
#
#    registration_gestation_weeks         phone_type   language  \
# 0                            17  smartphone_shared  Kiswahili
# 1                            26      feature_phone    English
# 2                            22  smartphone_shared      Kamba
# 3                            31      feature_phone      Kamba
# 4                            30  smartphone_shared        Luo
#
#    msgs_sent_pregnancy  msgs_sent_postpartum_6w  msgs_read_est  replies_total  \
# 0                   40                       15             38             18
# 1                   31                       19             25              7
# ...

# %%
# Check for missing values and data types

mothers_hmis_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   mother_id                   5000 non-null   int64
#  1   facility_id                 5000 non-null   str
#  2   county                      5000 non-null   str
#  3   residence_type              5000 non-null   str
#  4   age                         5000 non-null   int64
#  5   age_group                   5000 non-null   str
#  6   parity                      5000 non-null   int64
#  7   delivery_date               5000 non-null   str
#  8   delivery_mode               5000 non-null   str
#  9   complication_delivery       5000 non-null   str
#  10  postpartum_complication_6w  5000 non-null   int64
#  11  postnatal_visit_date_1      2898 non-null   str
#  12  postnatal_visit_6w          5000 non-null   int64
#  13  prompts_enrolled            5000 non-null   int64
# ...

# %% [markdown]
# ###### As shown in the above summary, only two columns; postnatal_visit_date_1 and prompts_mother_id, have missing values. These columns are expected to contain some empty entries, and no further action is required.

# %%
# Check for duplicates

duplicates = mothers_hmis_df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# ###### Because the dataset is synthetic and was generated with clean, consistent rules, it is ready for analysis without additional cleaning or preparation.
